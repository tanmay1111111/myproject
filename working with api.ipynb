# %%
import pandas as pd
import requests

# %%
response=requests.get('https://api.themoviedb.org/3/movie/top_rated?api_key=9497549b21cad8347a79d1389999e138&language=en-US&page=1')

# %%
response.json()
# Out:
# {'page': 1,
#  'results': [{'adult': False,
#    'backdrop_path': '/rl7Jw8PjhSIjArOlDNv0JQPL1ZV.jpg',
#    'genre_ids': [10749, 18],
#    'id': 851644,
#    'original_language': 'ko',
#    'original_title': '20세기 소녀',
#    'overview': "Yeon-du asks her best friend Bora to collect all the information she can about Baek Hyun-jin while she is away in the U.S. for heart surgery. Bora decides to get close to Baek's best friend, Pung Woon-ho first. However, Bora's clumsy plan unfolds in an unexpected direction. In 1999, a year before the new century, Bora, who turns seventeen, falls into the fever of first love.",
#    'popularity': 307.265,
#    'poster_path': '/od22ftNnyag0TTxcnJhlsu3aLoU.jpg',
#    'release_date': '2022-10-06',
#    'title': '20th Century Girl',
#    'video': False,
#    'vote_average': 8.7,
#    'vote_count': 279},
#   {'adult': False,
#    'backdrop_path': '/tmU7GeKVybMWFButWEGl2M4GeiP.jpg',
#    'genre_ids': [18, 80],
#    'id': 238,
#    'original_language': 'en',
# ...

# %%
df=pd.DataFrame(response.json()['results'])

# %%
df.head()
# Out:
#    adult                     backdrop_path    genre_ids      id  \
# 0  False  /rl7Jw8PjhSIjArOlDNv0JQPL1ZV.jpg  [10749, 18]  851644
# 1  False  /tmU7GeKVybMWFButWEGl2M4GeiP.jpg     [18, 80]     238
# 2  False  /kXfqcdQKsToO0OUXHcrrNCHDBzO.jpg     [18, 80]     278
# 3  False  /kGzFbGhp99zva6oZODW5atUtnqi.jpg     [18, 80]     240
# 4  False  /bxSBOAD8AuMHYMdW3jso9npAkgt.jpg  [10751, 18]  667257
#
#   original_language            original_title  \
# 0                ko                   20세기 소녀
# 1                en             The Godfather
# 2                en  The Shawshank Redemption
# 3                en     The Godfather Part II
# 4                es          Cosas imposibles
#
#                                             overview  popularity  \
# 0  Yeon-du asks her best friend Bora to collect a...     307.265
# 1  Spanning the years 1945 to 1955, a chronicle o...     107.568
# 2  Framed in the 1940s for the double murder of h...      90.229
# ...

# %%
df1=pd.DataFrame()

# %%
for i in range(1,429):
    response=requests.get('https://api.themoviedb.org/3/movie/top_rated?api_key=9497549b21cad8347a79d1389999e138&language=en-US&page={}'.format(i))
    temp_df=pd.DataFrame(response.json()['results'])
    df=df.append(temp_df,ignore_index=True)
# Out:
# C:\Users\MY HP\AppData\Local\Temp\ipykernel_10348\942523293.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df=df.append(temp_df,ignore_index=True)
# C:\Users\MY HP\AppData\Local\Temp\ipykernel_10348\942523293.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df=df.append(temp_df,ignore_index=True)
# C:\Users\MY HP\AppData\Local\Temp\ipykernel_10348\942523293.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df=df.append(temp_df,ignore_index=True)
# C:\Users\MY HP\AppData\Local\Temp\ipykernel_10348\942523293.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df=df.append(temp_df,ignore_index=True)
# ...

# %%
df.shape
# Out:
# (8580, 14)

# %%
df
# Out:
#       adult                     backdrop_path              genre_ids      id  \
# 0     False  /rl7Jw8PjhSIjArOlDNv0JQPL1ZV.jpg            [10749, 18]  851644
# 1     False  /tmU7GeKVybMWFButWEGl2M4GeiP.jpg               [18, 80]     238
# 2     False  /kXfqcdQKsToO0OUXHcrrNCHDBzO.jpg               [18, 80]     278
# 3     False  /kGzFbGhp99zva6oZODW5atUtnqi.jpg               [18, 80]     240
# 4     False  /bxSBOAD8AuMHYMdW3jso9npAkgt.jpg            [10751, 18]  667257
# ...     ...                               ...                    ...     ...
# 8575  False  /qRpoH1NgnsskEwKM8yR7Dkxzd76.jpg        [18, 35, 10749]   38970
# 8576  False  /zwB70O5riBoGEvAE2SAQ9Y6K4rN.jpg  [27, 9648, 53, 10402]  643550
# 8577  False  /h3ir8VfpSEtoEBJjEarEludkjKL.jpg          [28, 878, 53]  460648
# 8578  False  /4WRlyxjZnShSxoPgIxVa4fWx98f.jpg                   [18]   53399
# 8579  False  /td9f8E6W8Z2HnmmU69tT7ZHwK5F.jpg     [80, 53, 35, 9648]   27004
#
# ...

# %%
df.to_csv('movies.csv')
