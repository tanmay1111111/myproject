# %%
import pandas as pd

# %%
df=pd.read_csv('final.csv')
df.head()
# Out:
#    Unnamed: 0        name  rating          reviews     type  \
# 0           0         TCS     3.9  (50.8k Reviews)   Public
# 1           1   Accenture     4.1  (32.9k Reviews)   Public
# 2           2   Cognizant     3.9  (30.2k Reviews)  Private
# 3           3  ICICI Bank     4.0  (35.4k Reviews)   Public
# 4           4   HDFC Bank     4.0  (40.6k Reviews)   Public
#
#                                 hq           old                  employees
# 0    Mumbai,Maharashtra + 279 more  54 years old  1 Lakh+ Employees (India)
# 1                Dublin + 143 more  33 years old  1 Lakh+ Employees (India)
# 2  Teaneck. New Jersey. + 100 more  28 years old  1 Lakh+ Employees (India)
# 3   Mumbai,Maharashtra + 1048 more  28 years old  1 Lakh+ Employees (India)
# 4   Mumbai,Maharashtra + 1229 more  28 years old  1 Lakh+ Employees (India)

# %%
df['age']=df['old'].str.extract('(\d+)')

# %%
df.age.head()
# Out:
# 0    54
# 1    33
# 2    28
# 3    28
# 4    28
# Name: age, dtype: object

# %%
df['type'].value_counts()
# Out:
# Private                                    5706
# Public                                     1751
# LLP                                          39
# JV                                           33
# LLC                                          21
#                                            ...
# Princeton,New Jersey                          1
# Paonta Sahib,Himachal Pradesh + 11 more       1
# Burlington + 6 more                           1
# Riyadh + 10 more                              1
# Gurgaon/Gurugram + 5 more                     1
# Name: type, Length: 969, dtype: int64

# %%
df
# Out:
#       Unnamed: 0                 name  rating          reviews  \
# 0              0                  TCS     3.9  (50.8k Reviews)
# 1              1            Accenture     4.1  (32.9k Reviews)
# 2              2            Cognizant     3.9  (30.2k Reviews)
# 3              3           ICICI Bank     4.0  (35.4k Reviews)
# 4              4            HDFC Bank     4.0  (40.6k Reviews)
# ...          ...                  ...     ...              ...
# 8964          25           RICE GROUP     3.1     (60 Reviews)
# 8965          26  Vilas Javdekar D...     4.6     (60 Reviews)
# 8966          27  Spaco Technologi...     3.9     (60 Reviews)
# 8967          28          Tci Freight     4.1     (60 Reviews)
# 8968          29  Toshiba Water So...     3.7     (60 Reviews)
#
#                            type                               hq  \
# 0                        Public    Mumbai,Maharashtra + 279 more
# 1                        Public                Dublin + 143 more
# ...

# %%
df.drop(['old'],axis=1).copy()
# Out:
#       Unnamed: 0                 name  rating          reviews  \
# 0              0                  TCS     3.9  (50.8k Reviews)
# 1              1            Accenture     4.1  (32.9k Reviews)
# 2              2            Cognizant     3.9  (30.2k Reviews)
# 3              3           ICICI Bank     4.0  (35.4k Reviews)
# 4              4            HDFC Bank     4.0  (40.6k Reviews)
# ...          ...                  ...     ...              ...
# 8964          25           RICE GROUP     3.1     (60 Reviews)
# 8965          26  Vilas Javdekar D...     4.6     (60 Reviews)
# 8966          27  Spaco Technologi...     3.9     (60 Reviews)
# 8967          28          Tci Freight     4.1     (60 Reviews)
# 8968          29  Toshiba Water So...     3.7     (60 Reviews)
#
#                            type                               hq  \
# 0                        Public    Mumbai,Maharashtra + 279 more
# 1                        Public                Dublin + 143 more
# ...

# %%
df['review']=df['reviews'].str.extract('(\d+)')

# %%
df.review
# Out:
# 0       50
# 1       32
# 2       30
# 3       35
# 4       40
#         ..
# 8964    60
# 8965    60
# 8966    60
# 8967    60
# 8968    60
# Name: review, Length: 8969, dtype: object

# %%
df.head()
# Out:
#    Unnamed: 0        name  rating          reviews     type  \
# 0           0         TCS     3.9  (50.8k Reviews)   Public
# 1           1   Accenture     4.1  (32.9k Reviews)   Public
# 2           2   Cognizant     3.9  (30.2k Reviews)  Private
# 3           3  ICICI Bank     4.0  (35.4k Reviews)   Public
# 4           4   HDFC Bank     4.0  (40.6k Reviews)   Public
#
#                                 hq           old                  employees  \
# 0    Mumbai,Maharashtra + 279 more  54 years old  1 Lakh+ Employees (India)
# 1                Dublin + 143 more  33 years old  1 Lakh+ Employees (India)
# 2  Teaneck. New Jersey. + 100 more  28 years old  1 Lakh+ Employees (India)
# 3   Mumbai,Maharashtra + 1048 more  28 years old  1 Lakh+ Employees (India)
# 4   Mumbai,Maharashtra + 1229 more  28 years old  1 Lakh+ Employees (India)
#
#   age review
# 0  54     50
# 1  33     32
# 2  28     30
# 3  28     35
# 4  28     40

# %%
df
# Out:
#       Unnamed: 0                 name  rating          reviews  \
# 0              0                  TCS     3.9  (50.8k Reviews)
# 1              1            Accenture     4.1  (32.9k Reviews)
# 2              2            Cognizant     3.9  (30.2k Reviews)
# 3              3           ICICI Bank     4.0  (35.4k Reviews)
# 4              4            HDFC Bank     4.0  (40.6k Reviews)
# ...          ...                  ...     ...              ...
# 8964          25           RICE GROUP     3.1     (60 Reviews)
# 8965          26  Vilas Javdekar D...     4.6     (60 Reviews)
# 8966          27  Spaco Technologi...     3.9     (60 Reviews)
# 8967          28          Tci Freight     4.1     (60 Reviews)
# 8968          29  Toshiba Water So...     3.7     (60 Reviews)
#
#                            type                               hq  \
# 0                        Public    Mumbai,Maharashtra + 279 more
# 1                        Public                Dublin + 143 more
# ...

# %%
df['review']=df['review']+"0000"

# %%
df.head()
# Out:
#    Unnamed: 0        name  rating          reviews     type  \
# 0           0         TCS     3.9  (50.8k Reviews)   Public
# 1           1   Accenture     4.1  (32.9k Reviews)   Public
# 2           2   Cognizant     3.9  (30.2k Reviews)  Private
# 3           3  ICICI Bank     4.0  (35.4k Reviews)   Public
# 4           4   HDFC Bank     4.0  (40.6k Reviews)   Public
#
#                                 hq           old                  employees  \
# 0    Mumbai,Maharashtra + 279 more  54 years old  1 Lakh+ Employees (India)
# 1                Dublin + 143 more  33 years old  1 Lakh+ Employees (India)
# 2  Teaneck. New Jersey. + 100 more  28 years old  1 Lakh+ Employees (India)
# 3   Mumbai,Maharashtra + 1048 more  28 years old  1 Lakh+ Employees (India)
# 4   Mumbai,Maharashtra + 1229 more  28 years old  1 Lakh+ Employees (India)
#
#   age  review
# 0  54  500000
# 1  33  320000
# 2  28  300000
# 3  28  350000
# 4  28  400000

# %%
df['employee']=df['employees'].str.extract('(\d+)')

# %%
df['employee']=df['employee']+"00000"

# %%
df.head()
# Out:
#    Unnamed: 0        name  rating          reviews     type  \
# 0           0         TCS     3.9  (50.8k Reviews)   Public
# 1           1   Accenture     4.1  (32.9k Reviews)   Public
# 2           2   Cognizant     3.9  (30.2k Reviews)  Private
# 3           3  ICICI Bank     4.0  (35.4k Reviews)   Public
# 4           4   HDFC Bank     4.0  (40.6k Reviews)   Public
#
#                                 hq           old                  employees  \
# 0    Mumbai,Maharashtra + 279 more  54 years old  1 Lakh+ Employees (India)
# 1                Dublin + 143 more  33 years old  1 Lakh+ Employees (India)
# 2  Teaneck. New Jersey. + 100 more  28 years old  1 Lakh+ Employees (India)
# 3   Mumbai,Maharashtra + 1048 more  28 years old  1 Lakh+ Employees (India)
# 4   Mumbai,Maharashtra + 1229 more  28 years old  1 Lakh+ Employees (India)
#
#   age  review employee
# 0  54  500000   100000
# 1  33  320000   100000
# 2  28  300000   100000
# 3  28  350000   100000
# 4  28  400000   100000

# %%
df=df.drop(['employees'],axis=1)

# %%
df=df.drop(['old'],axis=1)

# %%
df.head()
# Out:
#    Unnamed: 0        name  rating          reviews     type  \
# 0           0         TCS     3.9  (50.8k Reviews)   Public
# 1           1   Accenture     4.1  (32.9k Reviews)   Public
# 2           2   Cognizant     3.9  (30.2k Reviews)  Private
# 3           3  ICICI Bank     4.0  (35.4k Reviews)   Public
# 4           4   HDFC Bank     4.0  (40.6k Reviews)   Public
#
#                                 hq age  review employee
# 0    Mumbai,Maharashtra + 279 more  54  500000   100000
# 1                Dublin + 143 more  33  320000   100000
# 2  Teaneck. New Jersey. + 100 more  28  300000   100000
# 3   Mumbai,Maharashtra + 1048 more  28  350000   100000
# 4   Mumbai,Maharashtra + 1229 more  28  400000   100000

# %%
df['reviews']=df['review'].str.extract('(\d+)')

# %%
df['reviews']
# Out:
# 0       500000
# 1       320000
# 2       300000
# 3       350000
# 4       400000
#          ...
# 8964    600000
# 8965    600000
# 8966    600000
# 8967    600000
# 8968    600000
# Name: reviews, Length: 8969, dtype: object

# %%
df.head()
# Out:
#    Unnamed: 0        name  rating reviews     type  \
# 0           0         TCS     3.9  500000   Public
# 1           1   Accenture     4.1  320000   Public
# 2           2   Cognizant     3.9  300000  Private
# 3           3  ICICI Bank     4.0  350000   Public
# 4           4   HDFC Bank     4.0  400000   Public
#
#                                 hq age  review employee
# 0    Mumbai,Maharashtra + 279 more  54  500000   100000
# 1                Dublin + 143 more  33  320000   100000
# 2  Teaneck. New Jersey. + 100 more  28  300000   100000
# 3   Mumbai,Maharashtra + 1048 more  28  350000   100000
# 4   Mumbai,Maharashtra + 1229 more  28  400000   100000

# %%
df['type'].value_counts()
# Out:
# Private                                    5706
# Public                                     1751
# LLP                                          39
# JV                                           33
# LLC                                          21
#                                            ...
# Princeton,New Jersey                          1
# Paonta Sahib,Himachal Pradesh + 11 more       1
# Burlington + 6 more                           1
# Riyadh + 10 more                              1
# Gurgaon/Gurugram + 5 more                     1
# Name: type, Length: 969, dtype: int64

# %%
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [34], in <cell line: 1>()
# ----> 1 df['type']={'Private':0,'Public':1,'LLP':2,'JV':3,'LLC':4}
#
# File ~\anaconda3\lib\site-packages\pandas\core\frame.py:3655, in DataFrame.__setitem__(self, key, value)
#    3652     self._setitem_array([key], value)
#    3653 else:
#    3654     # set column
# -> 3655     self._set_item(key, value)
#
# File ~\anaconda3\lib\site-packages\pandas\core\frame.py:3832, in DataFrame._set_item(self, key, value)
#    3822 def _set_item(self, key, value) -> None:
#    3823     """
#    3824     Add series to DataFrame in specified column.
#    3825
#    (...)
#    3830     ensure homogeneity.
#    3831     """
# -> 3832     value = self._sanitize_column(value)
#    3834     if (
#    3835         key in self.columns
#    3836         and value.ndim == 1
# ...
